# %% [markdown]
# <a href="https://colab.research.google.com/github/plg2001/FondamentiAI/blob/main/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🔷 Project Introduction
#
# Breast cancer is one of the leading causes of cancer-related morbidity worldwide, and early detection remains a crucial factor for improving patient outcomes. In this project, we aim to develop a multimodal deep learning framework capable of analyzing mammography and breast ultrasound images for tumor classification, representation learning, and synthetic data generation.
#
# The project is structured into three main components:
#
# 1. Mammography Analysis (CBIS-DDSM & INBreast)
#
# We first extract radiomic feature vectors from the CBIS-DDSM dataset and use them to train classification models capable of distinguishing benign from malignant lesions. INBreast is employed as an external testing set to evaluate the generalization capability of the trained models.
#
# 2. Ultrasound Image Generation (BUSI Dataset)
#
# To complement the mammography-based analysis, we implement a diffusion-model-based generator (“Mini-BUSGen”) trained on the BUSI breast ultrasound dataset. This module enables the creation of realistic synthetic ultrasound images conditioned on lesion type.
#
# 3. Multimodal Integration (Future Stage)
#
# Synthetic and real ultrasound images can be integrated with mammographic representations to build a multimodal diagnostic framework inspired by recent foundational models for breast cancer screening.
#
# This notebook serves as the starting point of the pipeline.
# We begin by importing all necessary libraries and loading the datasets from Google Drive.

# %% [markdown]
# # Preparation Phase

# %% [markdown]
# ##Import all library and Drive Mount

# %%
# --- 1. Core Libraries & File System ---
import os
import glob
import logging
from pathlib import Path

# --- 2. Data Handling ---
import pandas as pd
import numpy as np
import math

# --- 5. Deep Learning (PyTorch) ---
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

# --- 6. Transformers (Hugging Face) ---
# Per i modelli ViT, Swin, MMT (Fase 3)
# pip install transformers
try:
    import transformers
except ImportError:
    print("Transformers library not found. Install with: pip install transformers")

# --- 7. Utilities & Plotting ---
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt



print("Tutte le librerie del progetto sono state importate.")
print(f"PyTorch versione: {torch.__version__}")
# Google Colab integration

from google.colab import drive
drive.mount('/content/drive')

from PIL import Image
# Out:
# Tutte le librerie del progetto sono state importate.
# PyTorch versione: 2.9.0+cu126
# Mounted at /content/drive

# %% [markdown]
# ##Path Check

# %%
# ============================
# 📌 BASE PATH DELLA CARTELLA "dataset"
# ============================

# Nota: in Colab, "Il mio Drive" viene mappato come "/content/drive/MyDrive"
DATASET_BASE = "/content/drive/MyDrive/Colab Notebooks/Dataset"

# ============================
# 📌 CBIS-DDSM (modificato per la tua struttura)
# ============================

# La root di CBIS-DDSM è direttamente all'interno di DATASET_BASE
CBIS_ROOT = os.path.join(DATASET_BASE, "CBIS-DDSM")

# Le immagini sono dentro la sottocartella 'jpeg'
CBIS_IMAGES_PATH = os.path.join(CBIS_ROOT, "jpeg")

# I CSV sono dentro la sottocartella 'csv'
CBIS_CSV_PATH = os.path.join(CBIS_ROOT, "csv")

# ============================
# 📌 BUSI E INBREAST (come nel tuo codice originale)
# ============================

BUSI_PATH = os.path.join(DATASET_BASE, "BUSI")
INBREAST_PATH = os.path.join(DATASET_BASE, "INbreast")

# ============================
# 📦 STAMPA PERCORSI
# ============================

print("\n✔ Google Drive montato.")
print("========== Percorsi Dataset Aggiornati ==========")
print("Root: CBIS-DDSM         →", CBIS_ROOT)
print("Folder: CBIS-DDSM images →", CBIS_IMAGES_PATH)
print("Folder: CBIS-DDSM CSV    →", CBIS_CSV_PATH)
print("Square: BUSI              →", BUSI_PATH)
print("Dot: INBreast          →", INBREAST_PATH)

# ============================
# Checking: CHECK CARTELLE
# ============================

def check_folder(path, name):
    print(f"\nChecking {name}:")
    if os.path.exists(path):
        print("✔ Found")
    else:
        print(f"❌ {name} NOT FOUND! Incorrect path: {path}")

check_folder(CBIS_ROOT, "CBIS-DDSM Root") # Controlla la cartella principale
check_folder(CBIS_IMAGES_PATH, "CBIS-DDSM Images (jpeg)")
check_folder(CBIS_CSV_PATH, "CBIS-DDSM CSV")
check_folder(BUSI_PATH, "BUSI")
check_folder(INBREAST_PATH, "INbreast")

# ============================
# Checking: CHECK CSV CBIS-DDSM (AGGIUSTATO)
# ============================

required_csv = [
    "meta.csv",
    "calc_case_description_train_set.csv",
    "calc_case_description_test_set.csv",
    "mass_case_description_train_set.csv",
    "mass_case_description_test_set.csv",
]

print("\n========== Controllo CSV CBIS-DDSM ==========")

for csv_file in required_csv:
    # Ora la ricerca del file CSV avviene all'interno della sottocartella 'csv'
    path = os.path.join(CBIS_CSV_PATH, csv_file)
    if os.path.exists(path):
        print(f"✔ {csv_file} presente")
    else:
        print(f"❌ {csv_file} MANCANTE! (controlla il percorso: {path})")
# Out:
# ✔ Google Drive montato.
# ========== Percorsi Dataset Aggiornati ==========
# Root: CBIS-DDSM         → /content/drive/MyDrive/Colab Notebooks/Dataset/CBIS-DDSM
# Folder: CBIS-DDSM images → /content/drive/MyDrive/Colab Notebooks/Dataset/CBIS-DDSM/jpeg
# Folder: CBIS-DDSM CSV    → /content/drive/MyDrive/Colab Notebooks/Dataset/CBIS-DDSM/csv
# Square: BUSI              → /content/drive/MyDrive/Colab Notebooks/Dataset/BUSI
# Dot: INBreast          → /content/drive/MyDrive/Colab Notebooks/Dataset/INbreast
#
# Checking CBIS-DDSM Root:
# ✔ Found
#
# Checking CBIS-DDSM Images (jpeg):
# ✔ Found
#
# Checking CBIS-DDSM CSV:
# ✔ Found
#
# Checking BUSI:
# ✔ Found
#
# Checking INbreast:
# ✔ Found
#
# ========== Controllo CSV CBIS-DDSM ==========
# ✔ meta.csv presente
# ✔ calc_case_description_train_set.csv presente
# ✔ calc_case_description_test_set.csv presente
# ✔ mass_case_description_train_set.csv presente
# ✔ mass_case_description_test_set.csv presente

# %% [markdown]
# #***Classification Model***
#
#
#
# ![NN_PAPER1.pdf - Adobe Acrobat Reader (64-bit) 06_02_2026 16_44_05.png](data:image/png;base64,...)

# %% [markdown]
# ##Dataset Class

# %%
#Class for CBIS-DDSM dataset

import pandas as pd
import torch
from PIL import Image
from torch.utils.data import Dataset


class CBISDDSMPretrainDataset(Dataset):
    def __init__(self, csv_file, transform=None, n=4):
        self.df = pd.read_csv(csv_file)
        self.transform = transform
        self.n = n

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = Image.open(row["image_path"]).convert("L")

        if self.transform:
            img = self.transform(img)  # [1, H, W]

        # 🔑 DUPLICAZIONE IPERCOMPLESSA
        img = img.repeat(self.n, 1, 1)  # [n, H, W]

        label = torch.tensor(row["label"], dtype=torch.float32)
        return img, label

# %%
#Class for INBreast Dataset

import pandas as pd
import torch
from PIL import Image
from torch.utils.data import Dataset
import os


class INBreastDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.df = pd.read_csv(csv_file)
        self.transform = transform

    def _load_or_zero(self, path):
        if pd.isna(path) or not os.path.exists(path):
            # Crea immagine nera PIL
            img = Image.new("L", (224, 224))
        else:
            img = Image.open(path).convert("L")

        # 🔑 SEMPRE la stessa transform
        img = self.transform(img)        # [1,224,224]

        # lift quaternion
        img = img.repeat(4, 1, 1)        # [4,224,224]

        return img



    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        l_cc = self._load_or_zero(row["left_cc"])
        l_mlo = self._load_or_zero(row["left_mlo"])
        r_cc = self._load_or_zero(row["right_cc"])
        r_mlo = self._load_or_zero(row["right_mlo"])

        y_left = torch.tensor(row["label_left"], dtype=torch.float32)
        y_right = torch.tensor(row["label_right"], dtype=torch.float32)

        return l_cc, l_mlo, r_cc, r_mlo, y_left, y_right

# %%
#Utils function to do data augmentation of the images
import torchvision.transforms as T


def get_pretrain_transforms():
    return T.Compose([
        T.Resize((224,224)),
        T.RandomRotation(10),
        T.RandomHorizontalFlip(),
        T.ToTensor(),
    ])


def get_eval_transforms():
    return T.Compose(
        [
            T.Resize((500, 600)),
            T.ToTensor(),
        ]
    )

# %% [markdown]
# ##Models Class

# %%
class ComplexConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=0):
        super().__init__()
        assert in_channels % 2 == 0
        assert out_channels % 2 == 0

        self.real = nn.Conv2d(
            in_channels // 2,
            out_channels // 2,
            kernel_size,
            stride,
            padding,
            bias=False,
        )

        self.imag = nn.Conv2d(
            in_channels // 2,
            out_channels // 2,
            kernel_size,
            stride,
            padding,
            bias=False,
        )

    def forward(self, x):
        xr, xi = torch.chunk(x, 2, dim=1)

        real = self.real(xr) - self.imag(xi)
        imag = self.real(xi) + self.imag(xr)

        return torch.cat([real, imag], dim=1)


class QuaternionConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=0):
        super().__init__()
        assert in_channels % 4 == 0
        assert out_channels % 4 == 0

        self.r = nn.Conv2d(in_channels // 4, out_channels // 4, kernel_size, stride, padding, bias=False)
        self.i = nn.Conv2d(in_channels // 4, out_channels // 4, kernel_size, stride, padding, bias=False)
        self.j = nn.Conv2d(in_channels // 4, out_channels // 4, kernel_size, stride, padding, bias=False)
        self.k = nn.Conv2d(in_channels // 4, out_channels // 4, kernel_size, stride, padding, bias=False)

    def forward(self, x):
        xr, xi, xj, xk = torch.chunk(x, 4, dim=1)

        r = self.r(xr) - self.i(xi) - self.j(xj) - self.k(xk)
        i = self.r(xi) + self.i(xr) + self.j(xk) - self.k(xj)
        j = self.r(xj) - self.i(xk) + self.j(xr) + self.k(xi)
        k = self.r(xk) + self.i(xj) - self.j(xi) + self.k(xr)

        return torch.cat([r, i, j, k], dim=1)

# %%
class ComplexResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()

        self.conv1 = ComplexConv2d(channels, channels, 3, padding=1)
        self.bn1 = nn.BatchNorm2d(channels)
        self.relu = nn.ReLU(inplace=True)

        self.conv2 = ComplexConv2d(channels, channels, 3, padding=1)
        self.bn2 = nn.BatchNorm2d(channels)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        return self.relu(out + x)



class QuaternionResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()

        self.conv1 = QuaternionConv2d(channels, channels, 3, padding=1)
        self.bn1 = nn.BatchNorm2d(channels)
        self.relu = nn.ReLU(inplace=True)

        self.conv2 = QuaternionConv2d(channels, channels, 3, padding=1)
        self.bn2 = nn.BatchNorm2d(channels)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        return self.relu(out + x)

# %%
class QuaternionEncoder(nn.Module):
    def __init__(self, in_channels, base_channels=16, num_blocks=2):
        super().__init__()

        self.stem = nn.Sequential(
            QuaternionConv2d(in_channels, base_channels, 3, padding=1),
            nn.BatchNorm2d(base_channels),
            nn.ReLU(inplace=True),
        )

        self.blocks = nn.Sequential(
            *[QuaternionResidualBlock(base_channels) for _ in range(num_blocks)]
        )

    def forward(self, x):
        x = self.stem(x)
        return self.blocks(x)

# %%
class PHYBOnet(nn.Module):
    def __init__(self):
        super().__init__()

        # Encoder per seno sinistro e destro
        self.left_encoder = QuaternionEncoder(in_channels=8)
        self.right_encoder = QuaternionEncoder(in_channels=8)



        # Bottleneck patient-level (n = 4)
        self.bottleneck = nn.Sequential(
            QuaternionConv2d(32, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            *[QuaternionResidualBlock(32) for _ in range(4)],
        )

        self.pool = nn.AdaptiveAvgPool2d(1)
        self.fc_left = nn.Linear(32, 1)
        self.fc_right = nn.Linear(32, 1)

    def forward(self, l_cc, l_mlo, r_cc, r_mlo):
    # Breast-level (n = 2)
        left = torch.cat([l_cc, l_mlo], dim=1)
        right = torch.cat([r_cc, r_mlo], dim=1)

        f_left = self.left_encoder(left)
        f_right = self.right_encoder(right)

        # Patient-level (n = 4)
        fused = torch.cat([f_left, f_right], dim=1)
        fused = self.bottleneck(fused)

        pooled = self.pool(fused).flatten(1)

        y_left = self.fc_left(pooled)
        y_right = self.fc_right(pooled)

        return y_left, y_right

# %%
class PretrainQuaternionNet(nn.Module):
    def __init__(self):
        super().__init__()

        self.encoder = QuaternionEncoder(in_channels=4)

        self.pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(16, 1)

    def forward(self, x):
        x = self.encoder(x)
        x = self.pool(x).flatten(1)
        return self.fc(x).squeeze(1)

# %% [markdown]
# ##Pre-Training and Training

# %%
#Pretraining on crop images of CBIS-DDSM
from torch.utils.data import DataLoader
from tqdm import tqdm
# Importiamo autocast e GradScaler dal namespace moderno
from torch.amp import autocast, GradScaler


torch.cuda.empty_cache()

def pretrain_encoder(model, dataset, epochs=10, lr=1e-4, device="cuda"):
    loader = DataLoader(dataset, batch_size=4, shuffle=True)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()

    # Inizializziamo lo scaler per gestire il range dei gradienti in FP16
    scaler = GradScaler()

    model.to(device)
    model.train()

    for epoch in range(epochs):
        pbar = tqdm(loader, desc=f"[Pretrain] Epoch {epoch+1}/{epochs}")
        epoch_loss = 0.0

        for x, y in pbar:
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()

            # --- MIXED PRECISION START ---
            # Esegue il forward pass in precisione ridotta (autocast)
            with autocast(device_type='cuda'):
                out = model(x)  # [B]
                loss = criterion(out, y)

            # Scala la loss e calcola i gradienti
            scaler.scale(loss).backward()

            # scaler.step() si occupa di fare optimizer.step()
            # (ma prima "unscala" i gradienti)
            scaler.step(optimizer)

            # Aggiorna lo scaler per la prossima iterazione
            scaler.update()
            # --- MIXED PRECISION END ---

            epoch_loss += loss.item()
            pbar.set_postfix(loss=epoch_loss / (pbar.n + 1))

    # 🔑 Salva SOLO l'encoder
    torch.save(
        model.encoder.state_dict(),
        "/content/drive/MyDrive/Colab Notebooks/Weights Classification Model/quaternion_encoder_pretrained.pth"
    )

    print("Pretraining completato e pesi salvati!")

# %%
# training/train_four_view.py
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tqdm import tqdm
from torch.amp import autocast, GradScaler
import os
import pandas as pd
import numpy as np



def train_four_view(
    model,
    csv_file,
    transform,
    epochs=20,
    lr=1e-5,
    device="cuda",
    batch_size=4,
    seed=42,
):

    # ============================
    # 1️⃣ PATIENT-LEVEL SPLIT
    # ============================
    df = pd.read_csv(csv_file)

    patient_ids = df["patient_id"].unique()
    rng = np.random.default_rng(seed)
    rng.shuffle(patient_ids)

    split_idx = int(0.8 * len(patient_ids))
    train_patients = set(patient_ids[:split_idx])
    test_patients = set(patient_ids[split_idx:])

    train_df = df[df["patient_id"].isin(train_patients)]
    test_df = df[df["patient_id"].isin(test_patients)]

    print(
        f"📈 Patient-level split:"
        f"\n   Train patients: {len(train_patients)}"
        f"\n   Test  patients: {len(test_patients)}"
    )

    # ============================
    # 2️⃣ SAVE SPLIT CSV FILES
    # ============================
    os.makedirs("splits", exist_ok=True)

    train_csv = "/content/drive/MyDrive/Colab Notebooks/Splits On INBreast/inbreast_train_split.csv"
    test_csv = "/content/drive/MyDrive/Colab Notebooks/Splits On INBreast/inbreast_test_split.csv"

    train_df.to_csv(train_csv, index=False)
    test_df.to_csv(test_csv, index=False)

    # ============================
    # 3️⃣ DATASETS & LOADERS
    # ============================
    train_dataset = INBreastDataset(
        csv_file=train_csv,
        transform=transform,
    )

    test_dataset = INBreastDataset(
        csv_file=test_csv,
        transform=transform,
    )

    use_cuda = torch.cuda.is_available()
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=use_cuda,
    )

    # ============================
    # 4️⃣ OPTIM / LOSS
    # ============================
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()
    scaler = GradScaler()

    best_loss = float("inf")

    # ============================
    # 5️⃣ TRAINING LOOP
    # ============================
    for epoch in range(epochs):
        model.train()
        epoch_loss = 0.0

        pbar = tqdm(
            train_loader,
            desc=f"[Train] Epoch {epoch+1}/{epochs}",
        )

        for lcc, lmlo, rcc, rmlo, yl, yr in pbar:
            lcc = lcc.to(device)
            lmlo = lmlo.to(device)
            rcc = rcc.to(device)
            rmlo = rmlo.to(device)
            yl = yl.float().to(device)
            yr = yr.float().to(device)

            optimizer.zero_grad()

            with autocast(device_type=device):
                ypl, ypr = model(lcc, lmlo, rcc, rmlo)
                loss = (
                    criterion(ypl.squeeze(), yl)
                    + criterion(ypr.squeeze(), yr)
                )

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            epoch_loss += loss.item()
            pbar.set_postfix(loss=epoch_loss / (pbar.n + 1))

        avg_loss = epoch_loss / len(train_loader)
        print(f"[Epoch {epoch+1}] Train loss: {avg_loss:.4f}")

        if avg_loss < best_loss:
            best_loss = avg_loss
            torch.save(model.state_dict(), "/content/drive/MyDrive/Colab Notebooks/Weights Classification Model/phybonet_best.pth")

    # ============================
    # 6️⃣ FINAL SAVE
    # ============================
    torch.save(model.state_dict(), "/content/drive/MyDrive/Colab Notebooks/Weights Classification Model/phybonet_trained.pth")
    print("\n✅ Training completed. Model saved.")

    # ============================
    # 7️⃣ FINAL EVALUATION
    # ============================
    print("\n🚀 Final evaluation on TEST set (patient-level)...")

# %% [markdown]
# ##Main and Evaluation

# %%
import torch
import os

# @title ⚙️ Configurazione Pipeline PHYBOnet
# @markdown Select Mode
MODE = "train" # @param ["pretrain", "train"]
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

def main(mode):
    # Assicuriamoci che la cartella pesi esista
    os.makedirs("weights", exist_ok=True)

    # ==========================
    # 1️⃣ MODALITÀ PRETRAINING
    # ==========================
    if mode == "pretrain":
        print(f"\n🚀 [START] Pretraining encoder on CBIS-DDSM (Device: {DEVICE})")

        pretrain_dataset = CBISDDSMPretrainDataset(
            csv_file="/content/drive/MyDrive/Colab Notebooks/Dataset/CBIS-DDSM/csv/cbis_ddsm_classified_crops.csv",
            transform=get_pretrain_transforms(),
        )

        model = PretrainQuaternionNet().to(DEVICE)

        pretrain_encoder(
            model,
            pretrain_dataset,
            epochs=20,
            lr=1e-4,
            device=DEVICE,
        )

    # ==========================
    # 2️⃣ MODALITÀ FOUR-VIEW
    # ==========================
    elif mode == "train":
        print(f"\n🚀 [START] Training four-view model on INBreast (Device: {DEVICE})")

        # Controllo se esistono i pesi del pretrain
        pretrained_path = "/content/drive/MyDrive/Colab Notebooks/Weights Classification Model/quaternion_encoder_pretrained.pth"
        if not os.path.exists(pretrained_path):
            print(f"⚠️ Errore: Non trovo i pesi preaddestrati in {pretrained_path}")
            return

        model = PHYBOnet().to(DEVICE) # Ricordati il .to(DEVICE) qui!

        # Carica encoder pretrained
        print(f"📦 Caricamento pesi preaddestrati da {pretrained_path}...")
        state_dict = torch.load(pretrained_path, map_location=DEVICE)
        # model.load_state_dict(state_dict) # Ricorda di caricare effettivamente i pesi se necessario

        train_four_view(
            model=model,
            csv_file="/content/drive/MyDrive/Colab Notebooks/Dataset/INbreast/4view_INBreast.csv",
            transform=get_eval_transforms(),
            epochs=20,
            lr=1e-5,
            device=DEVICE,
        )

if __name__ == "__main__":
    main(MODE)

# %%
import torch
import os
import torch.nn as nn
from tqdm import tqdm
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, roc_auc_score
import csv


# =========================
# CONFIG
# =========================
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 4
WEIGHTS_PATH = "/content/drive/MyDrive/Colab Notebooks/Weights Classification Model/quaternion_encoder_pretrained.pth"
IMG_SIZE = 224  # deve essere UGUALE al pretraining
use_cuda = torch.cuda.is_available()

# ============================================================
# Valutazione encoder pretrained (linear evaluation protocol)
# ============================================================
@torch.no_grad()
def evaluate_pretrain(encoder, classifier, gap, dataset, device, save_csv=True):
    encoder.eval()
    classifier.eval()

    loader = DataLoader(
        dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=2,
        pin_memory=use_cuda,
    )

    criterion = nn.BCEWithLogitsLoss()

    total_loss = 0.0
    records = []  # <- per CSV

    print("\n📊 [EVAL] Valutazione encoder pretrained su CBIS-DDSM")

    for batch in tqdm(loader, desc="[Eval Pretrain]"):

        # Supporto dataset con o senza patient_id
        if len(batch) == 3:
            x, y, patient_ids = batch
        else:
            x, y = batch
            patient_ids = ["UNK"] * x.size(0)

        x = x.to(device)
        y = y.float().to(device)

        feats = encoder(x)
        feats = gap(feats)
        feats = feats.view(feats.size(0), -1)

        logits = classifier(feats).squeeze(1)
        loss = criterion(logits, y)
        total_loss += loss.item() * x.size(0)

        probs = torch.sigmoid(logits)

        # Salvataggio record
        for pid, prob, label in zip(patient_ids, probs.cpu(), y.cpu()):
            records.append({
                "patient_id": pid,
                "y_true": int(label.item()),
                "y_pred": float(prob.item()),
            })

    # Metriche
    avg_loss = total_loss / len(dataset)
    y_true = [r["y_true"] for r in records]
    y_pred = [r["y_pred"] for r in records]

    acc = accuracy_score(y_true, [p > 0.5 for p in y_pred])

    try:
        auc = roc_auc_score(y_true, y_pred)
    except ValueError:
        auc = float("nan")

    print("\n✅ RISULTATI PRETRAIN EVAL")
    print(f"   Loss:     {avg_loss:.4f}")
    print(f"   Accuracy: {acc:.4f}")
    print(f"   AUC:      {auc:.4f}")

    # =========================
    # SALVATAGGIO CSV
    # =========================
    if save_csv:
        os.makedirs("eval_outputs", exist_ok=True)
        csv_path = "/content/drive/MyDrive/Colab Notebooks/Classification Output/pretrain_predictions.csv"

        with open(csv_path, "w", newline="") as f:
            writer = csv.DictWriter(
                f,
                fieldnames=["patient_id", "y_true", "y_pred"]
            )
            writer.writeheader()
            writer.writerows(records)

        print(f"\n📁 CSV salvato in: {csv_path}")

    return {
        "loss": avg_loss,
        "accuracy": acc,
        "auc": auc,
    }


# =========================
# MAIN
# =========================
if __name__ == "__main__":

    # 1️⃣ Dataset CBIS-DDSM (cropped)
    dataset = CBISDDSMPretrainDataset(
        csv_file="/content/drive/MyDrive/Colab Notebooks/Dataset/CBIS-DDSM/csv/cbis_ddsm_classified_crops.csv",
        transform=get_pretrain_transforms(),
    )

    # 2️⃣ Encoder quaternionico (STESSO DEL PRETRAIN)
    encoder = QuaternionEncoder(in_channels=4).to(DEVICE)

    if not os.path.exists(WEIGHTS_PATH):
        raise FileNotFoundError(f"Pesi non trovati: {WEIGHTS_PATH}")

    state_dict = torch.load(WEIGHTS_PATH, map_location=DEVICE)
    encoder.load_state_dict(state_dict, strict=True)
    print("✅ Encoder pretrained caricato correttamente")

    # 3️⃣ Global Average Pooling
    gap = nn.AdaptiveAvgPool2d((1, 1))

    # 4️⃣ Calcolo automatico feature dimension
    with torch.no_grad():
        dummy = torch.zeros(1, 4, IMG_SIZE, IMG_SIZE).to(DEVICE)
        f = encoder(dummy)
        f = gap(f)
        feature_dim = f.view(1, -1).shape[1]

    print(f"ℹ️ Feature dimension encoder: {feature_dim}")

    # 5️⃣ Classificatore lineare (solo per valutazione)
    classifier = nn.Linear(feature_dim, 1).to(DEVICE)

    # 6️⃣ Valutazione
    evaluate_pretrain(
        encoder=encoder,
        classifier=classifier,
        gap=gap,
        dataset=dataset,
        device=DEVICE,
    )

# %%
import torch
import os
import csv
import torch.nn as nn
from tqdm import tqdm
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, roc_auc_score



# =========================
# CONFIG
# =========================
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 2
WEIGHTS_PATH = "/content/drive/MyDrive/Colab Notebooks/Weights Classification Model/phybonet_trained.pth"
CSV_OUT = "/content/drive/MyDrive/Colab Notebooks/Classification Output/train_predictions.csv"
use_cuda = torch.cuda.is_available()

# ============================================================
# Valutazione modello 4-view
# ============================================================
@torch.no_grad()
def evaluate_train(model, dataset, device, save_csv=True):
    model.eval()

    loader = DataLoader(
        dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=2,
        pin_memory=use_cuda,
    )

    criterion = nn.BCEWithLogitsLoss()
    records = []
    total_loss = 0.0

    print("\n📊 [EVAL] Valutazione modello 4-view su INBreast")

    for idx, batch in enumerate(tqdm(loader, desc="[Eval Train]")):

        if len(batch) == 7:
            lcc, lmlo, rcc, rmlo, yl, yr, patient_ids = batch
        else:
            lcc, lmlo, rcc, rmlo, yl, yr = batch
        # patient_id fittizio basato sull'indice
        patient_ids = [f"sample_{idx}_{i}" for i in range(lcc.size(0))]


        lcc  = lcc.to(device)
        lmlo = lmlo.to(device)
        rcc  = rcc.to(device)
        rmlo = rmlo.to(device)

        yl = yl.float().to(device)
        yr = yr.float().to(device)

        ypl, ypr = model(lcc, lmlo, rcc, rmlo)

        ypl = ypl.squeeze(1)
        ypr = ypr.squeeze(1)

        loss = criterion(ypl, yl) + criterion(ypr, yr)
        total_loss += loss.item() * lcc.size(0)

        pl = torch.sigmoid(ypl)
        pr = torch.sigmoid(ypr)

        for pid, tl, tr, pl_, pr_ in zip(
            patient_ids,
            yl.cpu(),
            yr.cpu(),
            pl.cpu(),
            pr.cpu(),
        ):
            records.append({
                "patient_id": pid,
                "y_left_true": int(tl.item()),
                "y_left_pred": float(pl_.item()),
                "y_right_true": int(tr.item()),
                "y_right_pred": float(pr_.item()),
            })

    # =========================
    # METRICHE
    # =========================
    avg_loss = total_loss / len(dataset)

    yl_true = [r["y_left_true"] for r in records]
    yl_pred = [r["y_left_pred"] for r in records]
    yr_true = [r["y_right_true"] for r in records]
    yr_pred = [r["y_right_pred"] for r in records]

    acc_l = accuracy_score(yl_true, [p > 0.5 for p in yl_pred])
    acc_r = accuracy_score(yr_true, [p > 0.5 for p in yr_pred])

    try:
        auc_l = roc_auc_score(yl_true, yl_pred)
    except ValueError:
        auc_l = float("nan")

    try:
        auc_r = roc_auc_score(yr_true, yr_pred)
    except ValueError:
        auc_r = float("nan")

    print("\n✅ RISULTATI TRAIN EVAL (INBreast)")
    print(f"   Loss medio: {avg_loss:.4f}")
    print(f"   Left  - Acc: {acc_l:.4f} | AUC: {auc_l:.4f}")
    print(f"   Right - Acc: {acc_r:.4f} | AUC: {auc_r:.4f}")

    # =========================
    # SALVATAGGIO CSV
    # =========================
    if save_csv:
        os.makedirs("eval_outputs", exist_ok=True)

        with open(CSV_OUT, "w", newline="") as f:
            writer = csv.DictWriter(
                f,
                fieldnames=[
                    "patient_id",
                    "y_left_true", "y_left_pred",
                    "y_right_true", "y_right_pred",
                ]
            )
            writer.writeheader()
            writer.writerows(records)

        print(f"\n📁 CSV salvato in: {CSV_OUT}")

    return {
        "loss": avg_loss,
        "auc_left": auc_l,
        "auc_right": auc_r,
        "acc_left": acc_l,
        "acc_right": acc_r,
    }


# =========================
# MAIN
# =========================
if __name__ == "__main__":

    # 1️⃣ Dataset INBreast
    dataset = INBreastDataset(
        csv_file="/content/drive/MyDrive/Colab Notebooks/Splits On INBreast/inbreast_test_split.csv",
        transform=get_eval_transforms(),
    )

    # 2️⃣ Modello
    model = PHYBOnet().to(DEVICE)

    if not os.path.exists(WEIGHTS_PATH):
        raise FileNotFoundError(f"Pesi non trovati: {WEIGHTS_PATH}")

    state_dict = torch.load(WEIGHTS_PATH, map_location=DEVICE)
    model.load_state_dict(state_dict, strict=True)

    print("✅ Modello 4-view caricato correttamente")

    # 3️⃣ Valutazione
    evaluate_train(
        model=model,
        dataset=dataset,
        device=DEVICE,
    )

# %% [markdown]
# #***Generative Model***

# %% [markdown]
# ###Feature extraction with PyRadiomics Library

# %%
# !pip install git+https://github.com/AIM-Harvard/pyradiomics
# !pip install SimpleITK

import os
import pandas as pd
import SimpleITK as sitk
from radiomics import featureextractor
from tqdm import tqdm
import logging
import numpy as np

# Silenzia i log ridondanti
logger = logging.getLogger("radiomics")
logger.setLevel(logging.ERROR)
np.seterr(over='ignore')

# =========================
# CONFIGURAZIONE
# =========================

INPUT_CSV = "/content/drive/MyDrive/Colab Notebooks/Dataset/CBIS-DDSM/csv/mammogram_roi_crop.csv"
OUTPUT_CSV = "/content/drive/MyDrive/Colab Notebooks/Dataset/CBIS-DDSM/csv/radiomics_features.csv"

IMAGE_COL = "full mammogram images"
MASK_COL = "ROI images"

META_COLS = ["PatientID", "Laterality", "PatientOrientation","label","Crop images"]
MAX_ROW = None # Imposta a un numero per limitare le righe processate (es. 100)

SELECTED_FEATURES = {
    "firstorder": ["Mean", "Variance", "Skewness", "Kurtosis", "Entropy", "Uniformity", "Energy", "Median", "InterquartileRange"],
    "glcm": ["Contrast", "Correlation", "JointEntropy", "JointEnergy", "Idm", "MCC"],
    "glrlm": ["ShortRunEmphasis", "LongRunEmphasis", "GrayLevelNonUniformityNormalized", "RunLengthNonUniformityNormalized", "RunEntropy"],
    "glszm": ["SmallAreaEmphasis", "LargeAreaEmphasis", "GrayLevelNonUniformityNormalized", "ZoneEntropy", "ZonePercentage"]
}

# =========================
# CORE FUNCTIONS
# =========================

def build_extractor():
    """Configura l'estrattore PyRadiomics."""
    extractor = featureextractor.RadiomicsFeatureExtractor(
        force2D=True,
        force2Ddimension=0,
        normalize=False,
        interpolator="sitkBSpline"
    )
    extractor.disableAllFeatures()
    for cls, feats in SELECTED_FEATURES.items():
        extractor.enableFeaturesByName(**{cls: feats})
    extractor.enableImageTypeByName("Original")
    return extractor

def resample_mask_to_image(image, mask):
    """
    Sincronizza la maschera sull'immagine se le dimensioni o lo spazio fisico differiscono.
    Usa Nearest Neighbor per preservare l'integrità della label.
    """
    if image.GetSize() != mask.GetSize() or image.GetSpacing() != mask.GetSpacing():
        resampler = sitk.ResampleImageFilter()
        resampler.SetReferenceImage(image)
        resampler.SetInterpolator(sitk.sitkNearestNeighbor)
        resampler.SetTransform(sitk.Transform())
        resampler.SetDefaultPixelValue(0)
        return resampler.Execute(mask)
    return mask

def filter_features(feature_dict):
    """Estrae solo i valori delle feature calcolate (escludendo info diagnostiche)."""
    return {k: float(v) for k, v in feature_dict.items() if k.startswith("original_")}

# =========================
# MAIN
# =========================

def main():
    if not os.path.exists(INPUT_CSV):
        print(f"Errore: File {INPUT_CSV} non trovato.")
        return

    df = pd.read_csv(INPUT_CSV)
    if MAX_ROW is not None:
        df = df.iloc[:MAX_ROW]

    extractor = build_extractor()
    rows = []

    print(f"--- Inizio estrazione su {len(df)} righe ---")

    for _, row in tqdm(df.iterrows(), total=len(df), desc="Processing", unit="ROI"):
        pid = row.get('PatientID', 'Unknown')
        try:
            # 1. Caricamento (senza forzare il tipo bit, mantenendo l'originale)
            img_path = row[IMAGE_COL]
            mask_path = row[MASK_COL]

            image = sitk.ReadImage(img_path)
            mask = sitk.ReadImage(mask_path)

            # 2. Resampling se necessario
            # Questo risolve l'errore LabelStatisticsImageFilter_Execute
            mask = resample_mask_to_image(image, mask)

            # 3. Estrazione
            features = extractor.execute(image, mask)
            features = filter_features(features)

            # 4. Aggregazione dati
            out_row = {col: row[col] for col in META_COLS}
            out_row.update(features)
            rows.append(out_row)

        except Exception as e:
            print(f"\n[ERRORE] Paziente {pid}: {str(e)}")
            continue

    # Salvataggio
    if rows:
        out_df = pd.DataFrame(rows)
        out_df.to_csv(OUTPUT_CSV, index=False)
        print(f"\n✔ Completato! Feature estratte: {len(out_df)}")
        print(f"✔ File salvato in: {OUTPUT_CSV}")
    else:
        print("\n✘ Nessuna feature estratta a causa di errori critici.")

if __name__ == "__main__":
    main()

# %%
import os
import shutil

ZIP_PATH = "/content/drive/MyDrive/Colab Notebooks/Dataset/dataset_completo.zip" # Il tuo nuovo zip
DEST_DIR = "/content/dataset_fast"

if os.path.exists(DEST_DIR):
    shutil.rmtree(DEST_DIR)
os.makedirs(DEST_DIR)

print(f"⏳ Scompattazione dataset completo in {DEST_DIR}...")
shutil.unpack_archive(ZIP_PATH, DEST_DIR)
print("✅ Fatto! Dataset pronto.")
# Out:
# ⏳ Scompattazione dataset completo in /content/dataset_fast...
# ✅ Fatto! Dataset pronto.

# %% [markdown]
# Start with training of generative model

# %%
import torch
import pandas as pd
import numpy as np
from torch.utils.data import Dataset
from PIL import Image
import os
from tqdm import tqdm

class INBreastRadiomicsDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None, scaler=None, phase='train', cache_images=True):
        print(f"📂 Inizializzazione Dataset con CSV: {csv_file}")
        self.data_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

        # 1. Trova le features (colonne che iniziano con 'original_')
        self.feature_cols = [c for c in self.data_frame.columns if 'original_' in c]
        if not self.feature_cols:
             raise ValueError("❌ ERRORE: Nessuna colonna 'original_' trovata nel CSV!")

        # 2. TROVA LA COLONNA IMMAGINI (Logica Migliorata)
        self.path_col = None

        # Tentativo A: Cerchiamo colonne con nomi noti
        known_names = ['Crop images', 'Crop_images', 'image', 'filename', 'path', 'File']
        for name in known_names:
            if name in self.data_frame.columns:
                self.path_col = name
                print(f"✅ Colonna immagini trovata per nome: '{self.path_col}'")
                break

        # Tentativo B: Se fallisce, cerchiamo colonne che contengono '.jpg' nei valori
        if self.path_col is None:
            print("⚠️ Ricerca colonna immagini tramite contenuto...")
            for col in self.data_frame.columns:
                # Controlla i primi 5 valori, convertili in stringa e cerca .jpg
                sample = self.data_frame[col].astype(str).head(5)
                if sample.str.contains('.jpg', case=False).any() or sample.str.contains('.png', case=False).any():
                    self.path_col = col
                    print(f"✅ Colonna immagini trovata per contenuto: '{self.path_col}'")
                    break

        if self.path_col is None:
            print("❌ Colonne disponibili:", self.data_frame.columns.tolist())
            raise ValueError("IMPOSSIBILE TROVARE LA COLONNA DELLE IMMAGINI NEL CSV. Controlla il nome.")

        # 3. Estrai Features
        self.features = self.data_frame[self.feature_cols].values.astype(np.float32)
        if phase == 'train' and scaler:
            self.features = scaler.transform(self.features)
        self.features = torch.tensor(self.features)

        # 4. CACHING IMMAGINI
        self.cache_images = cache_images
        self.cached_imgs = []

        if self.cache_images:
            print(f"🚀 Caching immagini da {root_dir}...")
            # Usa tqdm per vedere il progresso
            for idx in tqdm(range(len(self.data_frame)), desc="Loading RAM"):
                # Prendi il nome del file dal CSV
                filename = str(self.data_frame.iloc[idx][self.path_col]).strip()

                # Se il CSV ha ancora path assoluti, prendiamo solo il nome
                filename = os.path.basename(filename)

                # Costruisci il percorso completo nella cartella veloce
                img_path = os.path.join(self.root_dir, filename)

                try:
                    # Carica e Resize
                    with Image.open(img_path) as img: # Context manager per chiudere il file subito
                        img = img.convert('L')
                        img = img.resize((64, 64), Image.Resampling.LANCZOS)
                        # Copia in memoria per evitare riferimenti al file chiuso
                        self.cached_imgs.append(img.copy())
                except Exception as e:
                    # In caso di errore (file mancante), mettiamo un'immagine nera e avvisiamo
                    # print(f"⚠️ Warning: Immagine mancante o corrotta: {filename}")
                    self.cached_imgs.append(Image.new('L', (64, 64)))
            print("✅ Caching completato.")

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        if self.cache_images:
            image = self.cached_imgs[idx]
        else:
            # Fallback lento (lettura diretta)
            filename = str(self.data_frame.iloc[idx][self.path_col]).strip()
            filename = os.path.basename(filename)
            img_path = os.path.join(self.root_dir, filename)
            try:
                image = Image.open(img_path).convert('L')
                image = image.resize((64, 64), Image.Resampling.LANCZOS)
            except:
                image = Image.new('L', (64, 64))

        radiomics_vector = self.features[idx]

        if self.transform:
            image = self.transform(image)

        return image, radiomics_vector

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = math.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings

class Block(nn.Module):
    def __init__(self, in_ch, out_ch, time_emb_dim, dropout=0.1):
        super().__init__()
        self.time_mlp = nn.Linear(time_emb_dim, out_ch)
        self.norm1 = nn.GroupNorm(32, in_ch)
        self.conv1 = nn.Conv2d(in_ch, out_ch, 3, padding=1)
        self.norm2 = nn.GroupNorm(32, out_ch)
        self.conv2 = nn.Conv2d(out_ch, out_ch, 3, padding=1)
        self.relu = nn.SiLU()
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, t):
        h = self.norm1(x)
        h = self.relu(h)
        h = self.conv1(h)
        time_emb = self.relu(self.time_mlp(t))
        h = h + time_emb[(..., ) + (None, ) * 2]
        h = self.norm2(h)
        h = self.relu(h)
        h = self.dropout(h)
        h = self.conv2(h)
        return h

class Attention(nn.Module):
    def __init__(self, in_channels):
        super().__init__()
        self.norm = nn.GroupNorm(32, in_channels)
        self.qkv = nn.Conv2d(in_channels, in_channels * 3, 1)
        self.proj = nn.Conv2d(in_channels, in_channels, 1)

    def forward(self, x):
        B, C, H, W = x.shape
        x_norm = self.norm(x)
        qkv = self.qkv(x_norm)
        q, k, v = qkv.chunk(3, dim=1)

        q = q.permute(0, 2, 3, 1).reshape(B, H * W, C)
        k = k.permute(0, 2, 3, 1).reshape(B, H * W, C)
        v = v.permute(0, 2, 3, 1).reshape(B, H * W, C)

        scale = C ** -0.5
        attn = (q @ k.transpose(-2, -1)) * scale
        attn = attn.softmax(dim=-1)

        h = (attn @ v).reshape(B, H, W, C).permute(0, 3, 1, 2)
        h = self.proj(h)
        return x + h

class RadiomicsConditionedUNet(nn.Module):
    def __init__(self, radiomics_dim, img_channels=1, base_channels=32): # Default ridotto a 32
        super().__init__()
        self.base_channels = base_channels
        time_dim = base_channels * 4

        # Time Embedding
        self.time_mlp = nn.Sequential(
            SinusoidalPositionEmbeddings(base_channels),
            nn.Linear(base_channels, time_dim),
            nn.SiLU(),
            nn.Linear(time_dim, time_dim),
        )

        # Radiomics Embedding
        self.radiomics_mlp = nn.Sequential(
            nn.Linear(radiomics_dim, time_dim),
            nn.SiLU(),
            nn.Linear(time_dim, time_dim)
        )

        # Downsample
        self.inc = nn.Conv2d(img_channels, base_channels, 3, padding=1)

        # Level 1 (64x64) - NO ATTENTION (Troppo pesante)
        self.down1 = Block(base_channels, 64, time_dim)

        # Level 2 (32x32) - NO ATTENTION
        self.down2 = Block(64, 128, time_dim)

        # Bottleneck (16x16) - Qui l'Attention va bene ed è utile
        self.bot1 = Block(128, 256, time_dim)
        self.attn_bot = Attention(256)
        self.bot2 = Block(256, 256, time_dim) # Output 256 ch

        # Upsample
        self.up1 = Block(256 + 128, 128, time_dim)
        # Togliamo attn_up1

        self.up2 = Block(128 + 64, 64, time_dim)
        # Togliamo attn_up2

        self.up3 = Block(64 + base_channels, base_channels, time_dim)

        self.outc = nn.Conv2d(base_channels, img_channels, 1)

    def forward(self, x, t, radiomics):
        t_emb = self.time_mlp(t)
        r_emb = self.radiomics_mlp(radiomics)
        emb = t_emb + r_emb

        x1 = self.inc(x) # 64x64

        # Down 1
        x2 = self.down1(x1, emb) # 64x64
        x2_down = F.max_pool2d(x2, 2) # -> 32x32

        # Down 2
        x3 = self.down2(x2_down, emb) # 32x32
        x3_down = F.max_pool2d(x3, 2) # -> 16x16

        # Bottleneck
        x_bot = self.bot1(x3_down, emb)
        x_bot = self.attn_bot(x_bot)
        x_bot = self.bot2(x_bot, emb) # 16x16

        # Up 1 (16 -> 32)
        x_up1 = F.interpolate(x_bot, scale_factor=2, mode='nearest')
        x_up1 = torch.cat([x_up1, x3], dim=1)
        x_up1 = self.up1(x_up1, emb)

        # Up 2 (32 -> 64)
        x_up2 = F.interpolate(x_up1, scale_factor=2, mode='nearest')
        x_up2 = torch.cat([x_up2, x2], dim=1)
        x_up2 = self.up2(x_up2, emb)

        # Up 3 (Siamo già a 64x64, NON DOBBIAMO INGRANDIRE ANCORA)
        # ERRORE PRECEDENTE: scale_factor=2 portava a 128x128.
        # FIX: Manteniamo la dimensione attuale.
        x_up3 = x_up2

        # x1 è 64x64, x_up3 ora è 64x64. Concatenazione OK.
        x_up3 = torch.cat([x_up3, x1], dim=1)
        x_up3 = self.up3(x_up3, emb)

        return self.outc(x_up3)


class DiffusionModel(nn.Module):
    def __init__(self, model, timesteps=1000):
        super().__init__()
        self.model = model
        self.timesteps = timesteps
        beta = torch.linspace(1e-4, 0.02, timesteps)
        alpha = 1. - beta
        alpha_hat = torch.cumprod(alpha, dim=0)
        self.register_buffer('alpha_hat', alpha_hat)

    def sample_timesteps(self, n, device):
        return torch.randint(low=1, high=self.timesteps, size=(n,), device=device)

    def noise_images(self, x, t):
        sqrt_alpha_hat = torch.sqrt(self.alpha_hat[t])[:, None, None, None]
        sqrt_one_minus_alpha_hat = torch.sqrt(1 - self.alpha_hat[t])[:, None, None, None]
        epsilon = torch.randn_like(x)
        return sqrt_alpha_hat * x + sqrt_one_minus_alpha_hat * epsilon, epsilon

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from torch.amp import GradScaler, autocast
from sklearn.preprocessing import StandardScaler
import joblib
import pandas as pd
import os
from tqdm import tqdm
import math



# ==========================================
#              CONFIGURAZIONE
# ==========================================
# Modifica queste righe in train.py
IMG_ROOT = "/content/dataset_fast"
CSV_PATH = "/content/dataset_fast/radiomics_fixed.csv" # <--- Nota il nuovo nome!
CHECKPOINT_DIR = "/content/drive/MyDrive/Colab Notebooks/Checkpoint Generative Model"
PREVIEW_DIR = "/content/drive/MyDrive/Colab Notebooks/Preview Crop Images" # Nuova cartella per le immagini generate

os.makedirs(CHECKPOINT_DIR, exist_ok=True)
os.makedirs(PREVIEW_DIR, exist_ok=True)

# --- HYPERPARAMETERS ---
LR = 3e-4
IMG_SIZE = 64
TIMESTEPS = 1000
TOTAL_EPOCHS = 1000

# Frequenza salvataggio e anteprima
SAVE_AND_PREVIEW_EVERY = 50

# Batch & Accumulo
ACTUAL_BATCH_SIZE = 4
ACCUMULATION_STEPS = 8

LOAD_CHECKPOINT_PATH = None
# Esempio: LOAD_CHECKPOINT_PATH = "checkpoints/latest_checkpoint.pth"

# ==========================================
#        FUNZIONE GENERAZIONE ANTEPRIMA
# ==========================================
def generate_preview(model, radiomics_vector, epoch, device):
    """
    Genera un'immagine durante il training senza interromperlo.
    """
    model.eval() # Fondamentale: disattiva dropout/batchnorm

    with torch.no_grad():
        # Inizia da rumore puro
        x = torch.randn((1, 1, IMG_SIZE, IMG_SIZE)).to(device)

        # Parametri per il sampling (DDPM standard)
        # Ricalcoliamo qui localmente per evitare dipendenze complesse
        beta = torch.linspace(1e-4, 0.02, TIMESTEPS).to(device)
        alpha = 1. - beta
        alpha_hat = torch.cumprod(alpha, dim=0)

        # Loop inverso (T -> 0)
        for i in reversed(range(1, TIMESTEPS)):
            t = (torch.ones(1) * i).long().to(device)

            # Predizione rumore
            predicted_noise = model(x, t, radiomics_vector)

            # Calcolo coefficienti
            alpha_t = alpha[t][:, None, None, None]
            alpha_hat_t = alpha_hat[t][:, None, None, None]
            beta_t = beta[t][:, None, None, None]

            if i > 1:
                noise = torch.randn_like(x)
            else:
                noise = torch.zeros_like(x)

            # Formula DDPM: togliamo un po' di rumore
            x = (1 / torch.sqrt(alpha_t)) * (x - ((1 - alpha_t) / (torch.sqrt(1 - alpha_hat_t))) * predicted_noise) + torch.sqrt(beta_t) * noise

        # Salvataggio
        save_path = os.path.join(PREVIEW_DIR, f"preview_epoch_{epoch+1}.png")
        # Normalizziamo da [-1, 1] a [0, 1] per il png
        save_image((x.clamp(-1, 1) + 1) / 2, save_path)
        print(f"🖼️  Anteprima salvata: {save_path}")

    model.train() # Fondamentale: riattiva il training mode!

# ==========================================
#              TRAINING LOOP
# ==========================================

def train():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"🚀 Device attivo: {device}")

    # 1. Preparazione Dati
    print("📊 Preparazione dati...")
    df_temp = pd.read_csv(CSV_PATH)
    feature_cols = [c for c in df_temp.columns if 'original_' in c]

    scaler_path = os.path.join(CHECKPOINT_DIR, 'radiomics_scaler.pkl')
    if os.path.exists(scaler_path):
        scaler = joblib.load(scaler_path)
        print("Scaler caricato.")
    else:
        raw_features = df_temp[feature_cols].values
        scaler = StandardScaler()
        scaler.fit(raw_features)
        joblib.dump(scaler, scaler_path)
        print("Nuovo Scaler creato.")

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])

    dataset = INBreastRadiomicsDataset(
        csv_file=CSV_PATH,
        root_dir=IMG_ROOT,
        transform=transform,
        scaler=scaler,
        phase='train',
        cache_images=True
    )

    dataloader = DataLoader(dataset, batch_size=ACTUAL_BATCH_SIZE, shuffle=True, num_workers=0)

    # --- PREPARAZIONE VETTORE FISSO PER PREVIEW ---
    # Prendiamo il primo tumore del dataset e usiamo le sue features per generare le preview.
    # Così vediamo come evolve lo STESSO tumore nel tempo.
    print("🧪 Selezione vettore radiomico di test...")
    _, fixed_radiomics = dataset[0] # Prende il primo elemento
    fixed_radiomics = fixed_radiomics.unsqueeze(0).to(device) # Aggiunge batch dimension (1, features)

    # 2. Modello
    radiomics_dim = len(feature_cols)
    unet = RadiomicsConditionedUNet(radiomics_dim=radiomics_dim, base_channels=32).to(device)
    diffusion = DiffusionModel(unet, timesteps=TIMESTEPS).to(device)

    optimizer = optim.AdamW(unet.parameters(), lr=LR)
    scaler_amp = GradScaler()
    mse = nn.MSELoss()

    # 3. Resume
    start_epoch = 0
    if LOAD_CHECKPOINT_PATH and os.path.exists(LOAD_CHECKPOINT_PATH):
        print(f"🔄 Resume da: {LOAD_CHECKPOINT_PATH}")
        checkpoint = torch.load(LOAD_CHECKPOINT_PATH, map_location=device)
        unet.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        scaler_amp.load_state_dict(checkpoint['scaler_state_dict'])
        start_epoch = checkpoint['epoch']
    else:
        print("✨ Start from ZERO.")

    # 4. Loop
    unet.train()

    for epoch in range(start_epoch, TOTAL_EPOCHS):
        pbar = tqdm(dataloader)
        loss_epoch = 0
        optimizer.zero_grad()

        for i, (images, rad_features) in enumerate(pbar):
            images = images.to(device)
            rad_features = rad_features.to(device)

            t = diffusion.sample_timesteps(images.shape[0], device)
            x_t, noise = diffusion.noise_images(images, t)

            with autocast(device_type ='cuda'):
                predicted_noise = unet(x_t, t, rad_features)
                loss = mse(noise, predicted_noise)
                loss = loss / ACCUMULATION_STEPS

            scaler_amp.scale(loss).backward()

            if (i + 1) % ACCUMULATION_STEPS == 0:
                scaler_amp.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(unet.parameters(), 1.0)
                scaler_amp.step(optimizer)
                scaler_amp.update()
                optimizer.zero_grad()

            current_loss = loss.item() * ACCUMULATION_STEPS
            loss_epoch += current_loss
            pbar.set_description(f"Ep {epoch+1} | Loss: {current_loss:.4f}")

        avg_loss = loss_epoch / len(dataloader)
        print(f"Media Loss Epoca {epoch+1}: {avg_loss:.4f}")

        # SALVATAGGIO & PREVIEW
        # Salviamo il checkpoint latest SEMPRE (per sicurezza)
        checkpoint_dict = {
            'epoch': epoch + 1,
            'model_state_dict': unet.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scaler_state_dict': scaler_amp.state_dict(),
            'loss': avg_loss,
        }
        torch.save(checkpoint_dict, os.path.join(CHECKPOINT_DIR, "latest_checkpoint.pth"))

        # Ogni X epoche, facciamo il salvataggio storico e la GENERAZIONE
        if (epoch + 1) % SAVE_AND_PREVIEW_EVERY == 0:
            # 1. Salva storico
            hist_path = os.path.join(CHECKPOINT_DIR, f"ddpm_radiomics_ep{epoch+1}.pth")
            torch.save(checkpoint_dict, hist_path)

            # 2. Genera Anteprima
            print("⏳ Generazione anteprima in corso (attendere 10s)...")
            generate_preview(unet, fixed_radiomics, epoch, device)

    print("🎉 Training Completato!")

if __name__ == "__main__":
    try:
        train()
    except KeyboardInterrupt:
        print("\n🛑 Interrotto. Checkpoint salvato in 'latest_checkpoint.pth'.")
